# %%
# !pip uninstall -y transformers huggingface_hub diffusers accelerate

# !pip install transformers==4.36.2 huggingface_hub==0.20.3 accelerate==0.25.0 sentencepiece
# Out:
# Found existing installation: transformers 4.36.2
# Uninstalling transformers-4.36.2:
#   Successfully uninstalled transformers-4.36.2
# Found existing installation: huggingface-hub 0.20.3
# Uninstalling huggingface-hub-0.20.3:
#   Successfully uninstalled huggingface-hub-0.20.3
# WARNING: Skipping diffusers as it is not installed.
# Found existing installation: accelerate 0.25.0
# Uninstalling accelerate-0.25.0:
#   Successfully uninstalled accelerate-0.25.0
# ...
#   Using cached transformers-4.36.2-py3-none-any.whl.metadata (126 kB)
# ...
#   Using cached huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached accelerate-0.25.0-py3-none-any.whl.metadata (18 kB)
# ...
# Using cached transformers-4.36.2-py3-none-any.whl (8.2 MB)
# Using cached huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
# Using cached accelerate-0.25.0-py3-none-any.whl (265 kB)
# ...

# %%
from transformers import pipeline
from IPython.display import Image, display

# Pipelines
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
qa_pipeline = pipeline("question-answering")

# Input box
text = input("👉 Enter your text: ")

# SUMMARY
print("\n🔹 SUMMARY\n")
summary = summarizer(text, max_length=60, min_length=20, do_sample=False)
print(summary[0]['summary_text'])

# QUIZ
questions = [
    "What is the main topic?",
    "Where is it used?",
    "What are the benefits?",
    "Why is it important?",
    "Explain in short"
]

print("\n🔹 QUIZ\n")
for i, q in enumerate(questions, 1):
    ans = qa_pipeline(question=q, context=text)
    print(f"Q{i}: {q}")
    print("A:", ans['answer'])
    print()

# IMAGE
from IPython.display import Image, display

print("\n🔹 IMAGE\n")

# Simple working image (no errors)
display(Image(
    url="https://picsum.photos/400/300",
    width=350
))
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# 👉 Enter your text: Artificial Intelligence (AI) is a technology that allows machines to learn and make decisions like humans. It is widely used in healthcare for diagnosis, in education for smart learning, and in business for automation and data analysis. AI improves efficiency, saves time, and helps in solving complex problems. It is becoming an important part of our daily lives and shaping the future of technology.
#
# 🔹 SUMMARY
#
# Artificial Intelligence (AI) is a technology that allows machines to learn and make decisions like humans. It is widely used in healthcare for diagnosis, in education for smart learning, and in business for automation and data analysis.
#
# 🔹 QUIZ
#
# Q1: What is the main topic?
# ...
